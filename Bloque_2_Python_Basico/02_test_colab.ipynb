# %% [markdown]
# <a href="https://colab.research.google.com/github/tomassantiago-upp/intro-programacion-upp/blob/main/02_test_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# ⚡ PROTOCOLO DE CALIBRACIÓN - MARK I ⚡
# ==========================================

# INSTRUCCIÓN: Modifica ÚNICAMENTE los valores de estas 3 variables.
# No borres las comillas en los textos.

nombre_piloto = "ESTUDIANTE_DESCONOCIDO"  # <-- Pon tu nombre aquí
color_traje = "Gris Aburrido"           # <-- Pon tu color favorito aquí
nivel_energia = 10                      # <-- Pon un número del 1 al 100

# ==========================================
# 🛑 NO MODIFICAR EL CÓDIGO DE ABAJO 🛑
# ==========================================
import time

print("Iniciando sistemas...")
time.sleep(1)
print(f"Piloto reconocido: {nombre_piloto}")
time.sleep(1)
print(f"Aplicando pintura de titanio color: {color_traje}")
time.sleep(1)

if nivel_energia >= 80:
    print(f"Energía al {nivel_energia}%. Propulsores al máximo. ¡Listos para volar! 🚀")
elif nivel_energia >= 30:
    print(f"Energía al {nivel_energia}%. Sistemas estables, pero cuidado con los rayos repulsores. ⚡")
else:
    print(f"Energía crítica ({nivel_energia}%). Se requiere recarga inmediata. ⚠️")
