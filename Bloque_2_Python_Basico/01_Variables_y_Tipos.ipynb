# %% [markdown]
# <a href="https://colab.research.google.com/github/tomassantiago-upp/intro-programacion-upp/blob/main/Bloque_2_Python_Basico/01_Variables_y_Tipos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
estudiantes = 13
pi = 3.14159
mensaje = "Hola"
yaDesayune = False

print(type(estudiantes))
print(type(pi))
print(type(mensaje))
print(type(yaDesayune))

pi = int(pi)

print(pi)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 3
