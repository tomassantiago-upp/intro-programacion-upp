# %% [markdown]
# <a href="https://colab.research.google.com/github/tomassantiago-upp/intro-programacion-upp/blob/main/Bloque_2_Python_Basico/Semana4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercicio 1

def verificar_usuario():
    current_users = ["monica08", "ian08", "athena07", "lea07", "michelle08"]
    new_users = ["ATHENA07", "yael08", "fred08", "Ian08", "hector08"]
    available = True

    for new_user in new_users:
        for current_user in current_users:
            if new_user.lower() == current_user.lower():
                available = False
                break
            else:
                available = True
        if available:
            print(new_user + " está disponible")
        else:
            print("El nombre "+ new_user + " no está disponible. Elegir otro")


if __name__ == "__main__":
    verificar_usuario()

# %%
# Ejercicio 1 con complejidad O(n+m), más óptimo

def verificar_usuario():
    current_users = ["monica08", "ian08", "athena07", "lea07", "michelle08"]
    new_users = ["ATHENA07", "yael08", "fred08", "Ian08", "hector08"]

    # 1. Normalizamos a minúsculas y convertimos a set para búsqueda instantánea
    current_users_set = {user.lower() for user in current_users}
    new_users_set = {user.lower() for user in new_users}

    # 2. Encontramos la intersección (usuarios que ya existen)
    usuarios_tomados = current_users_set.intersection(new_users_set)

    # 3. Verificamos disponibilidad
    for user in new_users:
        if user.lower() in usuarios_tomados:
            print(f"El nombre {user} no está disponible. Elegir otro.")
        else:
            print(f"{user} está disponible.")

if __name__ == "__main__":
    verificar_usuario()

# %%
# Ejercicio 2 ADA 3

def ejecutar():
    estudiante1 = {
        "name":"Mónica",
        "ada": [10, 9, 10, 8, 10],
        "project": [10],
        "quizzes": [8, 7]
    }

    estudiante2 = {
        "name":"Yael",
        "ada": [10, 10, 10, 0, 8],
        "project": [9],
        "quizzes": [9, 10]
    }

    estudiante3 = {
        "name":"Florentino",
        "ada": [0, 6, 5, 0, 7],
        "project": [6],
        "quizzes": [5, 3]
    }

    estudiantes = [estudiante1, estudiante2, estudiante3]

    for estudiante in estudiantes:
        for x, y in estudiante.items():
            print(x,y)

    print(average(estudiante1["ada"]))

def average(numbers):
    suma = 0
    for number in numbers:
        suma += number
    return suma/len(numbers)


if __name__ == "__main__":
    ejecutar()
