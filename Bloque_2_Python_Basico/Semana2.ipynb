# %% [markdown]
# <a href="https://colab.research.google.com/github/tomassantiago-upp/intro-programacion-upp/blob/main/Bloque_2_Python_Basico/Semana2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejemplo de try/except

print("---Calculadora edad---")

while True:
    try:
    # Intentamos convertir la edad a un número
        edad_str = input("Ingresa tu edad: ")
        edad_num = int(edad_str)
        break

    except ValueError:
        # Si no es un número, muestra un error y vuelve al inicio
        print("ERROR: Dato inválido, favor de introducir un número.")

print("Tu edad dentro de 10 años es: ", edad_num + 10)

# %%
# Ejemplo 2 de try/except

print("---DIVISOR DE GASTOS DE MI STARTUP---")
presupuesto = 50000

try:
    empleados_str = input("Ingrese el número de empleados: ")
    empleados_num = int(empleados_str)
    bono_por_persona = presupuesto / empleados_num
    print("A cada empleado le toca un bono de: ", bono_por_persona)

except ValueError:
    print("ERROR: dato inválido, favor de introducir un número")

except ZeroDivisionError:
    print("ERROR: no puedes dividir entre 0 empleados.")

# %%
'''
EJERCICIO 1 ADA 2: Escribe un programa que le pregunte al usuario por una puntuación entre 0.0 y 1.0.
Usa el try/except para imprimir un mensaje de error en caso de que el usuario no introduzca un número;
verifica que el usuario introduzca un número dentro del rango solicitado en caso contrario imprime un
mensaje de error indicando que el valor está fuera de rango. Si la puntuación introducida está dentro del
rango imprime un nivel de aprendizaje usando la siguiente tabla:

Puntuación   Nivel de aprendizaje
>= 0.9     |  Estratégico
>= 0.8     |  Autónomo
>= 0.7     |  Resolutivo
>= 0.6     |  Receptivo
< 0.6      |  Preformal

'''

print("---Clasificador de calificaciones---")

while True:
  try:
    score_str = input("Introduce tu calificación en valores entre 0.0 y 1.0: ")
    score = float(score_str)

    if score > 1.0 or score < 0.0:
      print("Valores fuera de rango.")
      continue
    elif score >= 0.9:
      print("Nivel de aprendizaje: Estratégico")
    elif score >= 0.8:
      print("Nivel de aprendizaje: Autónomo")
    elif score >= 0.7:
      print("Nivel de aprendizaje: Resolutivo")
    elif score >= 0.6:
      print("Nivel de aprendizaje: Receptivo")
    else:
      print("Nivel de aprendizaje: Preformal")
    break
  except ValueError:
    print("Dato inválido. Favor de introducir un número entre 0.0 y 1.0")
# Out:
# ---Clasificador de calificaciones---
# Introduce tu calificación en valores entre 0.0 y 1.0: asdasd
# Dato inválido. Favor de introducir un número entre 0.0 y 1.0
# Introduce tu calificación en valores entre 0.0 y 1.0: punto seis
# Dato inválido. Favor de introducir un número entre 0.0 y 1.0
# Introduce tu calificación en valores entre 0.0 y 1.0: 0.75
# Nivel de aprendizaje: Resolutivo
